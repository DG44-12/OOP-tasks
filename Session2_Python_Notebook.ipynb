# %% [markdown]
# ***
# ## Implementing an OOP design
# ***
#
# The session 2 participant-led task is to complete the virtual pet simulation game. Look carefully at the Pet class UML diagram, in session 1 we coded most of the attributes and their getter and setter methods. Step-by-step, we'll code the additional methods that involve more complex processing.
#
# **Note:** As you update the Pet Class with the new methods, remmber to run it each time so that it loaded into memory and can be accessed by the test programs lower down.
#
# ![Pet Class-6.png](data:image/png;base64,...)

# %%
import random

class Pet:
  """Defines a pet in a children's game"""
  def __init__(self, given_name, given_type, given_colour):
    self.name = given_name
    self.type = given_type
    self.colour = given_colour
    all_moods = ["playful", "hungry", "sleepy"]
    self.mood = random.choice(all_moods)

  def get_name(self):
    return self.name

  def get_type(self):
    return self.type

  def get_colour(self):
    return self.colour

  def get_mood(self):
    return self.mood

  def is_sleeping(self):
    pass

  def describe(self):
    pass

  def set_name(self, new_name):
    self.name = new_name

  def set_type(self, new_type):
    self.type = new_type

  def set_colour(self, new_colour):
    self.colour = new_colour

  def play(self):
    pass

  def feed(self):
    pass

  def sleep(self):
    pass

  def wake(self):
    pass

# %% [markdown]
# ***
# ###  Task 1: A method that gets the value of several attributes
# ***
#
# - It is sometimes useful to have a method that returns or displays the value of more than one attribute. Consider the following example:
#
# ```
# PUBLIC PROCEDURE describe():
#         PRINT("I am a " + mood + ", " + colour + " " + type + " called " + name)
# ENDPROCEDURE
#
# ```
# - When the method is called, the following message will be displayed:
#
# ```
# I am a playful, ginger cat called Tiggy
# ```
#
# - Add this new method to the *Pet Class*
# - Run the Pet Class
# - Run the test program below.
#
# ***

# %%
#@title Run this program to test the describe method
pet_name = input("Enter the name of your pet ")
pet_type = input(f"What type of animal is {pet_name}? ")
pet_colour = input(f"What colour is {pet_name}? ")
my_pet = Pet(pet_name, pet_type, pet_colour)  # Instantiation
my_pet.describe()

# %% [markdown]
# ***
# ###  Task 2: Getters for Boolean values
# ***
#
# - Boolean variables can only take the values True or False. It is conventional to name getter methods for Boolean values using the prefix *is* rather than *get*. This helps make code self-documenting by using a more natural form of expression.
#
# - Consider the following example that adds a new attribute to the Pet class to record whether the pet is sleeping. The pet is sleeping or it is not sleeping. There are only two possible values for the attribute: True or False. The attribute will be initialised to *False* in the constructor, so newly created pets will start life awake.
#
# ```
# CLASS Pet
#     PRIVATE name: String
#     PRIVATE type: String
#     PRIVATE colour: String
#     PRIVATE mood: String
#     PRIVATE sleeping: Boolean
#
#     PUBLIC PROCEDURE Pet(given_name, given_type, given_colour)
#         name = given_name
#         type = given_type
#         colour = given_colour
#         all_moods = ["playful", "hungry", "sleepy"]
#         mood = RANDOM_CHOICE(all_moods)
#         sleeping = FALSE
#     ENDPROCEDURE
#
#     FUNCTION is_sleeping()
#         RETURN sleeping
#     ENDFUNCTION
#
#     ...
#   ```
#
# - Create the getter method *is_sleeping* for the new attribute
# - Update the Pet class to include the new *sleeping* attribute
# - Run the Pet Class above
# - Run the test program below
#
# ***

# %%
# @title Run this program to test the is_sleeping method
pet_name = input("Enter the name of your pet ")
pet_type = input(f"What type of animal is {pet_name}? ")
pet_colour = input(f"What colour is {pet_name}? ")
my_pet = Pet(pet_name, pet_type, pet_colour)  # Instantiation

if my_pet.is_sleeping():
    print(f"Shhhhhh, {pet_name} is asleep")
else:
    print(f"{pet_name} is awake")

# %% [markdown]
# ***
# ###  Task 3: Adding more methods to the class
# ***
#
# - So far you have seen methods that simply get and set the values of individual attributes. However, most classes will have additional methods that involve more complex processing.
#
# - The value of the mood attribute will only be updated when the player interacts with their pet by playing with it, feeding it, or putting it to bed. Interacting with the pet will affect its mood and this in turn will determine how the owner can interact with it. To implement this behaviour, you will write methods for play, feed, sleep, and wake.
#
# - First, consider the play method. This will only allow the pet to play if its mood is "playful", otherwise it will display a message explaining why it can't play. If it can play, it will do so and then the value of the mood attribute will be randomly set to "hungry", "sleepy", or "playful".
#
# ```
#  CLASS Pet
#
#  ....
#
#    PUBLIC PROCEDURE play()
#        IF sleeping == True THEN
#            PRINT("Zzzzzzz. I am sleeping")
#        ELSEIF mood == "hungry" THEN
#            PRINT("I am too hungry to play")
#        ELSEIF mood == "tired" THEN
#            PRINT("I am too tired to play")
#        ELSE
#            PRINT("This is fun, I love playing")
#            all_moods = ["playful", "hungry", "sleepy"]
#            self.mood = random.choice(all_moods)
#        ENDIF
#     ENDPROCEDURE
#
# ENDCLASS
# ```
#
# * Update the *play()* method in the *Pet* class
# * Run the test program below
# ***

# %%
# @title Run this program to test the play method
pet_name = input("Enter the name of your pet ")
pet_type = input(f"What type of animal is {pet_name}? ")
pet_colour = input(f"What colour is {pet_name}? ")
my_pet = Pet(pet_name, pet_type, pet_colour)  # Instantiation
my_pet.play()

# %% [markdown]
# ***
# ## Task 4: Feed, Sleep or Wake
# ***
#
# - Similar logic can be applied to write methods that allow a pet to feed, sleep, or wake:
#
# - Notice how these methods determine the rules for how the mood attribute can be modified.
#
# - The only way the value can be changed is by calling one of the methods. There is no setter method for the mood attribute and the rules of OOP mean that the attribute cannot be accessed directly because it is specified as private.
#
# - This is also true for the sleeping attribute. It can only be changed by the sleep or wake methods.
#
# ```
# CLASS Pet
#
# ....
#
#     PUBLIC PROCEDURE feed()
#         IF sleeping == True THEN
#             PRINT("Zzzzzzz. I am sleeping")
#         ENDIF
#         IF mood == "tired" THEN
#             PRINT("I am too sleepy to eat anything now")
#         ELSEIF mood == "playful" THEN
#             PRINT("I am not hungry - I want to play")
#         ELSE
#             PRINT("Yum - yum - that tastes great")
#             mood = "playful"
#         ENDIF
#     ENDPROCEDURE
#
#     PUBLIC PROCEDURE sleep()
#         IF mood == "playful" THEN
#             PRINT("I am too playful to sleep")
#         ELSEIF mood == "hungry" THEN
#             PRINT("I need something to eat before I can go to sleep")
#         ELSE
#             PRINT("Zzzzzzzz")
#             sleeping = True
#         ENDIF
#     ENDPROCEDURE
#
#
#     PUBLIC PROCEDURE wake()
#         IF sleeping == FALSE THEN
#            PRINT("I wasn't even asleep!")
#         ELSE
#             PRINT("I am awake and ready to play!")
#             sleeping = FALSE
#             mood = "playful"
#         ENDIF
#     ENDPROCEDURE
# ```
#
# * Use the pseudocode to update the *feed()*, *sleep()* and *wake()* methods in the *Pet* class
# * Run the Pet Class above
# * Run the test program below
# ***

# %%
#@title Run this program to test the feed, sleep and wake methods

def change_pet(my_pet):
  """Allows pet to be changed"""
  answer = input("\nDo you want to change the name of your pet(y/n)? ")
  if answer.lower() == "y":
    new_name = input("Enter a new name for your pet ")
    my_pet.set_name(new_name)
  answer = input("\nDo you want to change the type of pet you have(y/n)? ")
  if answer.lower() == "y":
    pet_name = my_pet.get_name()
    new_type = input(f"What type of animal is {pet_name}? ")
    my_pet.set_type(new_type)
  answer = input("\nDo you want to change the colour of your pet(y/n)? ")
  if answer.lower() == "y":
    pet_name = my_pet.get_name()
    new_colour = input(f"What colour is {pet_name}? ")
    my_pet.set_colour(new_colour)
  print("\n")
  my_pet.describe()

def show_game_options():
  """Options for game"""
  print ("\n")
  print ("  1. Feed your pet")
  print ("  2. Play with your pet")
  print ("  3. Put your pet to bed")
  print ("  4. Wake your pet up")
  print ("  5. Change pet")
  print ("  9. Finish the game")


pet_name = input("Enter a name for your pet ")
pet_type = input(f"What type of animal is {pet_name}? ")
pet_colour = input(f"What colour is {pet_name}? ")
my_pet = Pet(pet_name, pet_type, pet_colour) # Makes a pet object
finished = False
while finished == False:
  show_game_options()
  choice = input(" What do you want to do? ")
  print("\n")
  if choice == "1":
    my_pet.feed()
  elif choice == "2":
    my_pet.play()
  elif choice == "3":
    my_pet.sleep()
  elif choice == "4":
    my_pet.wake()
  elif choice == "5":
    change_pet(my_pet)
  elif choice == "9":
    finished = True # This will cause game to end
    print ("Thanks for playing the pet game")
  else:
      print("That is not a menu option")
